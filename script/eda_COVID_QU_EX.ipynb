# %%
#link Train dataset: https://www.kaggle.com/datasets/cf77495622971312010dd5934ee91f07ccbcfdea8e2f7778977ea8485c1914df

# %%
#import module

from Train_data import augs, img_de_normalize
from visualize import imshow_img_mask, visualize_distribute_dataset
from custom_dataset import ImageDataset
# from utils import transfms_M_STD, compute_mean_std
#import lib
import pandas as pd
import albumentations  as A
from albumentations.pytorch.transforms import ToTensorV2
import matplotlib.pyplot as plt
import os
from torch.utils.data import DataLoader
import torch
from tqdm import tqdm

# %%
# data_dir = './COVID_QU_Ex_dataset'
lung_data = '../COVID_QU_Ex_dataset/Lung Segmentation Data/Lung Segmentation Data/'
infection_dir = '../COVID_QU_Ex_dataset/Infection Segmentation Data/Infection Segmentation Data/'

# %%
# tao dict với key = file_name, value = label
label = os.listdir(lung_data+'Train')
dict_img = {}
for lbl in label:
    for file_name in os.listdir(lung_data+'Train/' +lbl +'/images'):
        dict_img[file_name]=lbl
dict_img
# Out:
# {'Normal (6599).png': 'Normal',
#  'Normal (2553).png': 'Normal',
#  'Normal (5219).png': 'Normal',
#  'Normal (1914).png': 'Normal',
#  'Normal (3940).png': 'Normal',
#  'Normal (5626).png': 'Normal',
#  'Normal (3643).png': 'Normal',
#  'Normal (10297).png': 'Normal',
#  'Normal (4416).png': 'Normal',
#  'Normal (3721).png': 'Normal',
#  'Normal (6316).png': 'Normal',
#  'Normal (10763).png': 'Normal',
#  'Normal (4896).png': 'Normal',
#  'Normal (3007).png': 'Normal',
#  'Normal (3877).png': 'Normal',
#  'Normal (5404).png': 'Normal',
#  'Normal (1809).png': 'Normal',
#  'Normal (6114).png': 'Normal',
#  'Normal (3377).png': 'Normal',
#  'Normal (2741).png': 'Normal',
#  'Normal (6506).png': 'Normal',
#  'Normal (2504).png': 'Normal',
#  'Normal (11826).png': 'Normal',
#  'Normal (2279).png': 'Normal',
#  'Normal (5325).png': 'Normal',
#  'Normal (6115).png': 'Normal',
#  'Normal (10878).png': 'Normal',
#  'Normal (3483).png': 'Normal',
#  'Normal (4993).png': 'Normal',
#  'Normal (10510).png': 'Normal',
#  'Normal (4145).png': 'Normal',
#  'Normal (5555).png': 'Normal',
#  'Normal (4847).png': 'Normal',
#  'Normal (11592).png': 'Normal',
#  'Normal (6510).png': 'Normal',
#  'Normal (2863).png': 'Normal',
#  'Normal (6171).png': 'Normal',
#  'Normal (5426).png': 'Normal',
#  'Normal (5660).png': 'Normal',
#  'Normal (4386).png': 'Normal',
#  'Normal (5575).png': 'Normal',
#  'Normal (2601).png': 'Normal',
#  'Normal (11310).png': 'Normal',
#  'Normal (5086).png': 'Normal',
#  'Normal (11675).png': 'Normal',
#  'Normal (11081).png': 'Normal',
#  'Normal (11265).png': 'Normal',
#  'Normal (4150).png': 'Normal',
#  'Normal (6586).png': 'Normal',
#  'Normal (1514).png': 'Normal',
#  'Normal (10673).png': 'Normal',
#  'Normal (2682).png': 'Normal',
#  'Normal (4036).png': 'Normal',
#  'Normal (10598).png': 'Normal',
#  'Normal (10452).png': 'Normal',
#  'Normal (10366).png': 'Normal',
#  'Normal (5837).png': 'Normal',
#  'Normal (2099).png': 'Normal',
#  'Normal (5924).png': 'Normal',
#  'Normal (4904).png': 'Normal',
#  'Normal (11297).png': 'Normal',
#  'Normal (4374).png': 'Normal',
#  'Normal (5309).png': 'Normal',
#  'Normal (4500).png': 'Normal',
#  'Normal (6019).png': 'Normal',
#  'Normal (4542).png': 'Normal',
#  'Normal (3254).png': 'Normal',
#  'Normal (5670).png': 'Normal',
#  'Normal (11173).png': 'Normal',
#  'Normal (10703).png': 'Normal',
#  'Normal (5808).png': 'Normal',
#  'Normal (4250).png': 'Normal',
#  'Normal (5854).png': 'Normal',
#  'Normal (3612).png': 'Normal',
#  'Normal (1628).png': 'Normal',
#  'Normal (6361).png': 'Normal',
#  'Normal (5634).png': 'Normal',
#  'Normal (3903).png': 'Normal',
#  'Normal (2296).png': 'Normal',
#  'Normal (5230).png': 'Normal',
#  'Normal (6365).png': 'Normal',
#  'Normal (4300).png': 'Normal',
#  'Normal (11323).png': 'Normal',
#  'Normal (3628).png': 'Normal',
#  'Normal (3297).png': 'Normal',
#  'Normal (6477).png': 'Normal',
#  'Normal (3317).png': 'Normal',
#  'Normal (3742).png': 'Normal',
#  'Normal (3526).png': 'Normal',
#  'Normal (4185).png': 'Normal',
#  'Normal (6296).png': 'Normal',
#  'Normal (3472).png': 'Normal',
#  'Normal (3850).png': 'Normal',
#  'Normal (10514).png': 'Normal',
#  'Normal (4641).png': 'Normal',
#  'Normal (11364).png': 'Normal',
#  'Normal (1703).png': 'Normal',
#  'Normal (3895).png': 'Normal',
#  'Normal (11346).png': 'Normal',
#  'Normal (11471).png': 'Normal',
#  'Normal (4456).png': 'Normal',
#  'Normal (4469).png': 'Normal',
#  'Normal (6437).png': 'Normal',
#  'Normal (3092).png': 'Normal',
#  'Normal (4046).png': 'Normal',
#  'Normal (3604).png': 'Normal',
#  'Normal (3454).png': 'Normal',
#  'Normal (3556).png': 'Normal',
#  'Normal (3378).png': 'Normal',
#  'Normal (3047).png': 'Normal',
#  'Normal (5020).png': 'Normal',
#  'Normal (10857).png': 'Normal',
#  'Normal (2387).png': 'Normal',
#  'Normal (11296).png': 'Normal',
#  'Normal (11908).png': 'Normal',
#  'Normal (2936).png': 'Normal',
#  'Normal (2633).png': 'Normal',
#  'Normal (10959).png': 'Normal',
#  'Normal (3257).png': 'Normal',
#  'Normal (10362).png': 'Normal',
#  'Normal (2329).png': 'Normal',
#  'Normal (6005).png': 'Normal',
#  'Normal (4871).png': 'Normal',
#  'Normal (10605).png': 'Normal',
#  'Normal (3543).png': 'Normal',
#  'Normal (3392).png': 'Normal',
#  'Normal (4383).png': 'Normal',
#  'Normal (1497).png': 'Normal',
#  'Normal (4990).png': 'Normal',
#  'Normal (5406).png': 'Normal',
#  'Normal (2890).png': 'Normal',
#  'Normal (10842).png': 'Normal',
#  'Normal (2052).png': 'Normal',
#  'Normal (3288).png': 'Normal',
#  'Normal (5093).png': 'Normal',
#  'Normal (1951).png': 'Normal',
#  'Normal (10966).png': 'Normal',
#  'Normal (2408).png': 'Normal',
#  'Normal (5712).png': 'Normal',
#  'Normal (3048).png': 'Normal',
#  'Normal (10489).png': 'Normal',
#  'Normal (2217).png': 'Normal',
#  'Normal (4640).png': 'Normal',
#  'Normal (4505).png': 'Normal',
#  'Normal (2465).png': 'Normal',
#  'Normal (5455).png': 'Normal',
#  'Normal (1424).png': 'Normal',
#  'Normal (5486).png': 'Normal',
#  'Normal (4285).png': 'Normal',
#  'Normal (10460).png': 'Normal',
#  'Normal (5905).png': 'Normal',
#  'Normal (2108).png': 'Normal',
#  'Normal (6432).png': 'Normal',
#  'Normal (4238).png': 'Normal',
#  'Normal (3396).png': 'Normal',
#  'Normal (5857).png': 'Normal',
#  'Normal (3508).png': 'Normal',
#  'Normal (11825).png': 'Normal',
#  'Normal (6056).png': 'Normal',
#  'Normal (3957).png': 'Normal',
#  'Normal (3209).png': 'Normal',
#  'Normal (4858).png': 'Normal',
#  'Normal (1550).png': 'Normal',
#  'Normal (10376).png': 'Normal',
#  'Normal (3154).png': 'Normal',
#  'Normal (11317).png': 'Normal',
#  'Normal (4940).png': 'Normal',
#  'Normal (1825).png': 'Normal',
#  'Normal (10897).png': 'Normal',
#  'Normal (10688).png': 'Normal',
#  'Normal (5633).png': 'Normal',
#  'Normal (2251).png': 'Normal',
#  'Normal (3379).png': 'Normal',
#  'Normal (11755).png': 'Normal',
#  'Normal (1411).png': 'Normal',
#  'Normal (2854).png': 'Normal',
#  'Normal (6193).png': 'Normal',
#  'Normal (1577).png': 'Normal',
#  'Normal (5611).png': 'Normal',
#  'Normal (3322).png': 'Normal',
#  'Normal (3734).png': 'Normal',
#  'Normal (4289).png': 'Normal',
#  'Normal (5649).png': 'Normal',
#  'Normal (1807).png': 'Normal',
#  'Normal (5206).png': 'Normal',
#  'Normal (2324).png': 'Normal',
#  'Normal (5685).png': 'Normal',
#  'Normal (4096).png': 'Normal',
#  'Normal (5267).png': 'Normal',
#  'Normal (5864).png': 'Normal',
#  'Normal (2240).png': 'Normal',
#  'Normal (2027).png': 'Normal',
#  'Normal (2760).png': 'Normal',
#  'Normal (2019).png': 'Normal',
#  'Normal (4012).png': 'Normal',
#  'Normal (2517).png': 'Normal',
#  'Normal (4849).png': 'Normal',
#  'Normal (1529).png': 'Normal',
#  'Normal (11674).png': 'Normal',
#  'Normal (1714).png': 'Normal',
#  'Normal (10337).png': 'Normal',
#  'Normal (5799).png': 'Normal',
#  'Normal (11965).png': 'Normal',
#  'Normal (11053).png': 'Normal',
#  'Normal (6350).png': 'Normal',
#  'Normal (4482).png': 'Normal',
#  'Normal (4683).png': 'Normal',
#  'Normal (3709).png': 'Normal',
#  'Normal (10702).png': 'Normal',
#  'Normal (10803).png': 'Normal',
#  'Normal (11090).png': 'Normal',
#  'Normal (4230).png': 'Normal',
#  'Normal (5536).png': 'Normal',
#  'Normal (10837).png': 'Normal',
#  'Normal (6045).png': 'Normal',
#  'Normal (5307).png': 'Normal',
#  'Normal (3591).png': 'Normal',
#  'Normal (6423).png': 'Normal',
#  'Normal (5029).png': 'Normal',
#  'Normal (1831).png': 'Normal',
#  'Normal (3467).png': 'Normal',
#  'Normal (4339).png': 'Normal',
#  'Normal (3590).png': 'Normal',
#  'Normal (1968).png': 'Normal',
#  'Normal (5731).png': 'Normal',
#  'Normal (2138).png': 'Normal',
#  'Normal (2057).png': 'Normal',
#  'Normal (3913).png': 'Normal',
#  'Normal (6141).png': 'Normal',
#  'Normal (1847).png': 'Normal',
#  'Normal (11501).png': 'Normal',
#  'Normal (2538).png': 'Normal',
#  'Normal (10490).png': 'Normal',
#  'Normal (11722).png': 'Normal',
#  'Normal (10902).png': 'Normal',
#  'Normal (11064).png': 'Normal',
#  'Normal (11429).png': 'Normal',
#  'Normal (4039).png': 'Normal',
#  'Normal (3337).png': 'Normal',
#  'Normal (2047).png': 'Normal',
#  'Normal (4549).png': 'Normal',
#  'Normal (3490).png': 'Normal',
#  'Normal (6044).png': 'Normal',
#  'Normal (3424).png': 'Normal',
#  'Normal (2818).png': 'Normal',
#  'Normal (2308).png': 'Normal',
#  'Normal (4611).png': 'Normal',
#  'Normal (5379).png': 'Normal',
#  'Normal (10800).png': 'Normal',
#  'Normal (6507).png': 'Normal',
#  'Normal (4624).png': 'Normal',
#  'Normal (2468).png': 'Normal',
#  'Normal (3524).png': 'Normal',
#  'Normal (11701).png': 'Normal',
#  'Normal (4596).png': 'Normal',
#  'Normal (10730).png': 'Normal',
#  'Normal (4972).png': 'Normal',
#  'Normal (3290).png': 'Normal',
#  'Normal (6009).png': 'Normal',
#  'Normal (6195).png': 'Normal',
#  'Normal (6166).png': 'Normal',
#  'Normal (2514).png': 'Normal',
#  'Normal (10381).png': 'Normal',
#  'Normal (2339).png': 'Normal',
#  'Normal (10744).png': 'Normal',
#  'Normal (10689).png': 'Normal',
#  'Normal (10398).png': 'Normal',
#  'Normal (6032).png': 'Normal',
#  'Normal (10942).png': 'Normal',
#  'Normal (6175).png': 'Normal',
#  'Normal (5840).png': 'Normal',
#  'Normal (11706).png': 'Normal',
#  'Normal (3466).png': 'Normal',
#  'Normal (5720).png': 'Normal',
#  'Normal (6211).png': 'Normal',
#  'Normal (10853).png': 'Normal',
#  'Normal (3229).png': 'Normal',
#  'Normal (6512).png': 'Normal',
#  'Normal (3547).png': 'Normal',
#  'Normal (6431).png': 'Normal',
#  'Normal (5770).png': 'Normal',
#  'Normal (10926).png': 'Normal',
#  'Normal (3213).png': 'Normal',
#  'Normal (10783).png': 'Normal',
#  'Normal (5884).png': 'Normal',
#  'Normal (2211).png': 'Normal',
#  'Normal (2165).png': 'Normal',
#  'Normal (5009).png': 'Normal',
#  'Normal (2398).png': 'Normal',
#  'Normal (11134).png': 'Normal',
#  'Normal (11171).png': 'Normal',
#  'Normal (5476).png': 'Normal',
#  'Normal (1791).png': 'Normal',
#  'Normal (3815).png': 'Normal',
#  'Normal (4066).png': 'Normal',
#  'Normal (3324).png': 'Normal',
#  'Normal (3255).png': 'Normal',
#  'Normal (4894).png': 'Normal',
#  'Normal (1652).png': 'Normal',
#  'Normal (3195).png': 'Normal',
#  'Normal (11565).png': 'Normal',
#  'Normal (1457).png': 'Normal',
#  'Normal (11136).png': 'Normal',
#  'Normal (3003).png': 'Normal',
#  'Normal (4929).png': 'Normal',
#  'Normal (5539).png': 'Normal',
#  'Normal (10720).png': 'Normal',
#  'Normal (3752).png': 'Normal',
#  'Normal (5791).png': 'Normal',
#  'Normal (5106).png': 'Normal',
#  'Normal (5393).png': 'Normal',
#  'Normal (3110).png': 'Normal',
#  'Normal (5751).png': 'Normal',
#  'Normal (10952).png': 'Normal',
#  'Normal (1557).png': 'Normal',
#  'Normal (11112).png': 'Normal',
#  'Normal (4129).png': 'Normal',
#  'Normal (5587).png': 'Normal',
#  'Normal (5158).png': 'Normal',
#  'Normal (4510).png': 'Normal',
#  'Normal (11620).png': 'Normal',
#  'Normal (1555).png': 'Normal',
#  'Normal (6418).png': 'Normal',
#  'Normal (11567).png': 'Normal',
#  'Normal (2280).png': 'Normal',
#  'Normal (3062).png': 'Normal',
#  'Normal (1690).png': 'Normal',
#  'Normal (3937).png': 'Normal',
#  'Normal (3224).png': 'Normal',
#  'Normal (11975).png': 'Normal',
#  'Normal (3223).png': 'Normal',
#  'Normal (10781).png': 'Normal',
#  'Normal (10595).png': 'Normal',
#  'Normal (1855).png': 'Normal',
#  'Normal (11733).png': 'Normal',
#  'Normal (6395).png': 'Normal',
#  'Normal (4528).png': 'Normal',
#  'Normal (6597).png': 'Normal',
#  'Normal (1445).png': 'Normal',
#  'Normal (5051).png': 'Normal',
#  'Normal (11747).png': 'Normal',
#  'Normal (11167).png': 'Normal',
#  'Normal (2077).png': 'Normal',
#  'Normal (2985).png': 'Normal',
#  'Normal (5699).png': 'Normal',
#  'Normal (10501).png': 'Normal',
#  'Normal (3883).png': 'Normal',
#  'Normal (11857).png': 'Normal',
#  'Normal (4060).png': 'Normal',
#  'Normal (5262).png': 'Normal',
#  'Normal (4810).png': 'Normal',
#  'Normal (10951).png': 'Normal',
#  'Normal (2136).png': 'Normal',
#  'Normal (4623).png': 'Normal',
#  'Normal (11329).png': 'Normal',
#  'Normal (10788).png': 'Normal',
#  'Normal (11904).png': 'Normal',
#  'Normal (4876).png': 'Normal',
#  'Normal (6111).png': 'Normal',
#  'Normal (5878).png': 'Normal',
#  'Normal (11989).png': 'Normal',
#  'Normal (11883).png': 'Normal',
#  'Normal (6006).png': 'Normal',
#  'Normal (10575).png': 'Normal',
#  'Normal (11169).png': 'Normal',
#  'Normal (3600).png': 'Normal',
#  'Normal (10645).png': 'Normal',
#  'Normal (1836).png': 'Normal',
#  'Normal (10344).png': 'Normal',
#  'Normal (11198).png': 'Normal',
#  'Normal (6194).png': 'Normal',
#  'Normal (11325).png': 'Normal',
#  'Normal (1696).png': 'Normal',
#  'Normal (3140).png': 'Normal',
#  'Normal (10503).png': 'Normal',
#  'Normal (4604).png': 'Normal',
#  'Normal (6464).png': 'Normal',
#  'Normal (2110).png': 'Normal',
#  'Normal (3701).png': 'Normal',
#  'Normal (10536).png': 'Normal',
#  'Normal (4243).png': 'Normal',
#  'Normal (10784).png': 'Normal',
#  'Normal (4837).png': 'Normal',
#  'Normal (4448).png': 'Normal',
#  'Normal (10980).png': 'Normal',
#  'Normal (5105).png': 'Normal',
#  'Normal (5440).png': 'Normal',
#  'Normal (6295).png': 'Normal',
#  'Normal (2270).png': 'Normal',
#  'Normal (5329).png': 'Normal',
#  'Normal (5550).png': 'Normal',
#  'Normal (10748).png': 'Normal',
#  'Normal (1973).png': 'Normal',
#  'Normal (5478).png': 'Normal',
#  'Normal (2758).png': 'Normal',
#  'Normal (5843).png': 'Normal',
#  'Normal (11629).png': 'Normal',
#  'Normal (5926).png': 'Normal',
#  'Normal (10589).png': 'Normal',
#  'Normal (1490).png': 'Normal',
#  'Normal (11022).png': 'Normal',
#  'Normal (10500).png': 'Normal',
#  'Normal (2739).png': 'Normal',
#  'Normal (3143).png': 'Normal',
#  'Normal (11413).png': 'Normal',
#  'Normal (3361).png': 'Normal',
#  'Normal (6427).png': 'Normal',
#  'Normal (4086).png': 'Normal',
#  'Normal (3059).png': 'Normal',
#  'Normal (11643).png': 'Normal',
#  'Normal (5521).png': 'Normal',
#  'Normal (5823).png': 'Normal',
#  'Normal (5459).png': 'Normal',
#  'Normal (3773).png': 'Normal',
#  'Normal (4332).png': 'Normal',
#  'Normal (2284).png': 'Normal',
#  'Normal (3784).png': 'Normal',
#  'Normal (11694).png': 'Normal',
#  'Normal (2731).png': 'Normal',
#  'Normal (11083).png': 'Normal',
#  'Normal (6483).png': 'Normal',
#  'Normal (11634).png': 'Normal',
#  'Normal (5224).png': 'Normal',
#  'Normal (10920).png': 'Normal',
#  'Normal (3082).png': 'Normal',
#  'Normal (5806).png': 'Normal',
#  'Normal (3557).png': 'Normal',
#  'Normal (2727).png': 'Normal',
#  'Normal (11625).png': 'Normal',
#  'Normal (11725).png': 'Normal',
#  'Normal (10327).png': 'Normal',
#  'Normal (2940).png': 'Normal',
#  'Normal (5446).png': 'Normal',
#  'Normal (11520).png': 'Normal',
#  'Normal (3520).png': 'Normal',
#  'Normal (5126).png': 'Normal',
#  'Normal (11616).png': 'Normal',
#  'Normal (5785).png': 'Normal',
#  'Normal (3675).png': 'Normal',
#  'Normal (11245).png': 'Normal',
#  'Normal (11886).png': 'Normal',
#  'Normal (5546).png': 'Normal',
#  'Normal (2405).png': 'Normal',
#  'Normal (3191).png': 'Normal',
#  'Normal (10872).png': 'Normal',
#  'Normal (1866).png': 'Normal',
#  'Normal (5834).png': 'Normal',
#  'Normal (11898).png': 'Normal',
#  'Normal (3521).png': 'Normal',
#  'Normal (11969).png': 'Normal',
#  'Normal (3060).png': 'Normal',
#  'Normal (2039).png': 'Normal',
#  'Normal (3731).png': 'Normal',
#  'Normal (2694).png': 'Normal',
#  'Normal (10643).png': 'Normal',
#  'Normal (11861).png': 'Normal',
#  'Normal (3644).png': 'Normal',
#  'Normal (2283).png': 'Normal',
#  'Normal (2827).png': 'Normal',
#  'Normal (2886).png': 'Normal',
#  'Normal (5096).png': 'Normal',
#  'Normal (10574).png': 'Normal',
#  'Normal (3331).png': 'Normal',
#  'Normal (4044).png': 'Normal',
#  'Normal (3085).png': 'Normal',
#  'Normal (10513).png': 'Normal',
#  'Normal (6461).png': 'Normal',
#  'Normal (3289).png': 'Normal',
#  'Normal (6555).png': 'Normal',
#  'Normal (2448).png': 'Normal',
#  'Normal (1884).png': 'Normal',
#  'Normal (11865).png': 'Normal',
#  'Normal (11182).png': 'Normal',
#  'Normal (1597).png': 'Normal',
#  'Normal (4954).png': 'Normal',
#  'Normal (11727).png': 'Normal',
#  'Normal (2937).png': 'Normal',
#  'Normal (3161).png': 'Normal',
#  'Normal (11088).png': 'Normal',
#  'Normal (4602).png': 'Normal',
#  'Normal (6153).png': 'Normal',
#  'Normal (1655).png': 'Normal',
#  'Normal (5727).png': 'Normal',
#  'Normal (10378).png': 'Normal',
#  'Normal (2822).png': 'Normal',
#  'Normal (11361).png': 'Normal',
#  'Normal (4540).png': 'Normal',
#  'Normal (11092).png': 'Normal',
#  'Normal (11972).png': 'Normal',
#  'Normal (1848).png': 'Normal',
#  'Normal (1539).png': 'Normal',
#  'Normal (4610).png': 'Normal',
#  'Normal (11484).png': 'Normal',
#  'Normal (2836).png': 'Normal',
#  'Normal (2383).png': 'Normal',
#  'Normal (4575).png': 'Normal',
#  'Normal (2852).png': 'Normal',
#  'Normal (2794).png': 'Normal',
#  'Normal (5312).png': 'Normal',
#  'Normal (4317).png': 'Normal',
#  'Normal (11773).png': 'Normal',
#  'Normal (1616).png': 'Normal',
#  'Normal (2443).png': 'Normal',
#  'Normal (1626).png': 'Normal',
#  'Normal (6559).png': 'Normal',
#  'Normal (2833).png': 'Normal',
#  'Normal (6429).png': 'Normal',
#  'Normal (1661).png': 'Normal',
#  'Normal (4763).png': 'Normal',
#  'Normal (5326).png': 'Normal',
#  'Normal (5254).png': 'Normal',
#  'Normal (5317).png': 'Normal',
#  'Normal (1567).png': 'Normal',
#  'Normal (3924).png': 'Normal',
#  'Normal (11145).png': 'Normal',
#  'Normal (3306).png': 'Normal',
#  'Normal (5159).png': 'Normal',
#  'Normal (2648).png': 'Normal',
#  'Normal (3613).png': 'Normal',
#  'Normal (2867).png': 'Normal',
#  'Normal (6272).png': 'Normal',
#  'Normal (5661).png': 'Normal',
#  'Normal (11453).png': 'Normal',
#  'Normal (5184).png': 'Normal',
#  'Normal (1568).png': 'Normal',
#  'Normal (10435).png': 'Normal',
#  'Normal (6140).png': 'Normal',
#  'Normal (11619).png': 'Normal',
#  'Normal (6149).png': 'Normal',
#  'Normal (11213).png': 'Normal',
#  'Normal (10484).png': 'Normal',
#  'Normal (6024).png': 'Normal',
#  'Normal (3656).png': 'Normal',
#  'Normal (11992).png': 'Normal',
#  'Normal (4158).png': 'Normal',
#  'Normal (11170).png': 'Normal',
#  'Normal (5079).png': 'Normal',
#  'Normal (6362).png': 'Normal',
#  'Normal (6144).png': 'Normal',
#  'Normal (2178).png': 'Normal',
#  'Normal (2631).png': 'Normal',
#  'Normal (5464).png': 'Normal',
#  'Normal (3409).png': 'Normal',
#  'Normal (4997).png': 'Normal',
#  'Normal (4801).png': 'Normal',
#  'Normal (11615).png': 'Normal',
#  'Normal (5172).png': 'Normal',
#  'Normal (10543).png': 'Normal',
#  'Normal (1629).png': 'Normal',
#  'Normal (2725).png': 'Normal',
#  'Normal (11912).png': 'Normal',
#  'Normal (6467).png': 'Normal',
#  'Normal (11369).png': 'Normal',
#  'Normal (5411).png': 'Normal',
#  'Normal (6425).png': 'Normal',
#  'Normal (10544).png': 'Normal',
#  'Normal (3989).png': 'Normal',
#  'Normal (1668).png': 'Normal',
#  'Normal (6112).png': 'Normal',
#  'Normal (4196).png': 'Normal',
#  'Normal (4620).png': 'Normal',
#  'Normal (6124).png': 'Normal',
#  'Normal (4174).png': 'Normal',
#  'Normal (4829).png': 'Normal',
#  'Normal (4385).png': 'Normal',
#  'Normal (10475).png': 'Normal',
#  'Normal (11224).png': 'Normal',
#  'Normal (2250).png': 'Normal',
#  'Normal (10900).png': 'Normal',
#  'Normal (3655).png': 'Normal',
#  'Normal (6181).png': 'Normal',
#  'Normal (3528).png': 'Normal',
#  'Normal (4387).png': 'Normal',
#  'Normal (10355).png': 'Normal',
#  'Normal (11168).png': 'Normal',
#  'Normal (5388).png': 'Normal',
#  'Normal (11759).png': 'Normal',
#  'Normal (10367).png': 'Normal',
#  'Normal (1901).png': 'Normal',
#  'Normal (11914).png': 'Normal',
#  'Normal (11299).png': 'Normal',
#  'Normal (4131).png': 'Normal',
#  'Normal (4009).png': 'Normal',
#  'Normal (6040).png': 'Normal',
#  'Normal (2313).png': 'Normal',
#  'Normal (2664).png': 'Normal',
#  'Normal (10740).png': 'Normal',
#  'Normal (11054).png': 'Normal',
#  'Normal (10296).png': 'Normal',
#  'Normal (11005).png': 'Normal',
#  'Normal (4108).png': 'Normal',
#  'Normal (10528).png': 'Normal',
#  'Normal (5891).png': 'Normal',
#  'Normal (5133).png': 'Normal',
#  'Normal (5188).png': 'Normal',
#  'Normal (4047).png': 'Normal',
#  'Normal (3823).png': 'Normal',
#  'Normal (3074).png': 'Normal',
#  'Normal (11113).png': 'Normal',
#  'Normal (11154).png': 'Normal',
#  'Normal (5059).png': 'Normal',
#  'Normal (2563).png': 'Normal',
#  'Normal (2391).png': 'Normal',
#  'Normal (2556).png': 'Normal',
#  'Normal (5152).png': 'Normal',
#  'Normal (2807).png': 'Normal',
#  'Normal (2594).png': 'Normal',
#  'Normal (2532).png': 'Normal',
#  'Normal (11678).png': 'Normal',
#  'Normal (3851).png': 'Normal',
#  'Normal (5896).png': 'Normal',
#  'Normal (11541).png': 'Normal',
#  'Normal (4938).png': 'Normal',
#  'Normal (1908).png': 'Normal',
#  'Normal (2261).png': 'Normal',
#  'Normal (6227).png': 'Normal',
#  'Normal (10750).png': 'Normal',
#  'Normal (5259).png': 'Normal',
#  'Normal (4632).png': 'Normal',
#  'Normal (11451).png': 'Normal',
#  'Normal (10893).png': 'Normal',
#  'Normal (2510).png': 'Normal',
#  'Normal (6076).png': 'Normal',
#  'Normal (3730).png': 'Normal',
#  'Normal (4654).png': 'Normal',
#  'Normal (2291).png': 'Normal',
#  'Normal (10330).png': 'Normal',
#  'Normal (2485).png': 'Normal',
#  'Normal (3690).png': 'Normal',
#  'Normal (2539).png': 'Normal',
#  'Normal (5208).png': 'Normal',
#  'Normal (10308).png': 'Normal',
#  'Normal (11204).png': 'Normal',
#  'Normal (4964).png': 'Normal',
#  'Normal (10580).png': 'Normal',
#  'Normal (11990).png': 'Normal',
#  'Normal (6167).png': 'Normal',
#  'Normal (3384).png': 'Normal',
#  'Normal (4591).png': 'Normal',
#  'Normal (2172).png': 'Normal',
#  'Normal (3484).png': 'Normal',
#  'Normal (4730).png': 'Normal',
#  'Normal (1753).png': 'Normal',
#  'Normal (4106).png': 'Normal',
#  'Normal (5943).png': 'Normal',
#  'Normal (1659).png': 'Normal',
#  'Normal (4278).png': 'Normal',
#  'Normal (2017).png': 'Normal',
#  'Normal (2497).png': 'Normal',
#  'Normal (4946).png': 'Normal',
#  'Normal (5321).png': 'Normal',
#  'Normal (1934).png': 'Normal',
#  'Normal (3775).png': 'Normal',
#  'Normal (5248).png': 'Normal',
#  'Normal (6168).png': 'Normal',
#  'Normal (6353).png': 'Normal',
#  'Normal (4818).png': 'Normal',
#  'Normal (11051).png': 'Normal',
#  'Normal (5675).png': 'Normal',
#  'Normal (3079).png': 'Normal',
#  'Normal (1819).png': 'Normal',
#  'Normal (4947).png': 'Normal',
#  'Normal (11516).png': 'Normal',
#  'Normal (3881).png': 'Normal',
#  'Normal (3277).png': 'Normal',
#  'Normal (10601).png': 'Normal',
#  'Normal (1938).png': 'Normal',
#  'Normal (6242).png': 'Normal',
#  'Normal (2646).png': 'Normal',
#  'Normal (11765).png': 'Normal',
#  'Normal (2176).png': 'Normal',
#  'Normal (10463).png': 'Normal',
#  'Normal (4295).png': 'Normal',
#  'Normal (1916).png': 'Normal',
#  'Normal (4159).png': 'Normal',
#  'Normal (2208).png': 'Normal',
#  'Normal (5821).png': 'Normal',
#  'Normal (6148).png': 'Normal',
#  'Normal (11985).png': 'Normal',
#  'Normal (1591).png': 'Normal',
#  'Normal (6038).png': 'Normal',
#  'Normal (10357).png': 'Normal',
#  'Normal (1462).png': 'Normal',
#  'Normal (10326).png': 'Normal',
#  'Normal (10709).png': 'Normal',
#  'Normal (5629).png': 'Normal',
#  'Normal (4541).png': 'Normal',
#  'Normal (5487).png': 'Normal',
#  'Normal (4621).png': 'Normal',
#  'Normal (3606).png': 'Normal',
#  'Normal (1798).png': 'Normal',
#  'Normal (2723).png': 'Normal',
#  'Normal (2527).png': 'Normal',
#  'Normal (4252).png': 'Normal',
#  'Normal (3451).png': 'Normal',
#  'Normal (2493).png': 'Normal',
#  'Normal (5461).png': 'Normal',
#  'Normal (5782).png': 'Normal',
#  'Normal (5777).png': 'Normal',
#  'Normal (6120).png': 'Normal',
#  'Normal (2097).png': 'Normal',
#  'Normal (5604).png': 'Normal',
#  'Normal (4771).png': 'Normal',
#  'Normal (3084).png': 'Normal',
#  'Normal (5205).png': 'Normal',
#  'Normal (11754).png': 'Normal',
#  'Normal (4840).png': 'Normal',
#  'Normal (6502).png': 'Normal',
#  'Normal (6489).png': 'Normal',
#  'Normal (11500).png': 'Normal',
#  'Normal (3416).png': 'Normal',
#  'Normal (4532).png': 'Normal',
#  'Normal (5946).png': 'Normal',
#  'Normal (4394).png': 'Normal',
#  'Normal (3806).png': 'Normal',
#  'Normal (11143).png': 'Normal',
#  'Normal (5780).png': 'Normal',
#  'Normal (6354).png': 'Normal',
#  'Normal (1725).png': 'Normal',
#  'Normal (6275).png': 'Normal',
#  'Normal (6255).png': 'Normal',
#  'Normal (2975).png': 'Normal',
#  'Normal (10821).png': 'Normal',
#  'Normal (11131).png': 'Normal',
#  'Normal (5089).png': 'Normal',
#  'Normal (4396).png': 'Normal',
#  'Normal (4059).png': 'Normal',
#  'Normal (10354).png': 'Normal',
#  'Normal (10999).png': 'Normal',
#  'Normal (10573).png': 'Normal',
#  'Normal (5708).png': 'Normal',
#  'Normal (11076).png': 'Normal',
#  'Normal (3599).png': 'Normal',
#  'Normal (2713).png': 'Normal',
#  'Normal (3653).png': 'Normal',
#  'Normal (6303).png': 'Normal',
#  'Normal (5175).png': 'Normal',
#  'Normal (4951).png': 'Normal',
#  'Normal (4709).png': 'Normal',
#  'Normal (5602).png': 'Normal',
#  'Normal (2419).png': 'Normal',
#  'Normal (10386).png': 'Normal',
#  'Normal (6448).png': 'Normal',
#  'Normal (3260).png': 'Normal',
#  'Normal (2466).png': 'Normal',
#  'Normal (11653).png': 'Normal',
#  'Normal (6343).png': 'Normal',
#  'Normal (4756).png': 'Normal',
#  'Normal (11262).png': 'Normal',
#  'Normal (10819).png': 'Normal',
#  'Normal (4647).png': 'Normal',
#  'Normal (6561).png': 'Normal',
#  'Normal (10555).png': 'Normal',
#  'Normal (4107).png': 'Normal',
#  'Normal (2635).png': 'Normal',
#  'Normal (5829).png': 'Normal',
#  'Normal (2218).png': 'Normal',
#  'Normal (4802).png': 'Normal',
#  'Normal (4045).png': 'Normal',
#  'Normal (6422).png': 'Normal',
#  'Normal (6573).png': 'Normal',
#  'Normal (3541).png': 'Normal',
#  'Normal (10694).png': 'Normal',
#  'Normal (2496).png': 'Normal',
#  'Normal (3968).png': 'Normal',
#  'Normal (3475).png': 'Normal',
#  'Normal (1524).png': 'Normal',
#  'Normal (3009).png': 'Normal',
#  'Normal (10565).png': 'Normal',
#  'Normal (5090).png': 'Normal',
#  'Normal (11110).png': 'Normal',
#  'Normal (1609).png': 'Normal',
#  'Normal (5768).png': 'Normal',
#  'Normal (3004).png': 'Normal',
#  'Normal (3332).png': 'Normal',
#  'Normal (2507).png': 'Normal',
#  'Normal (11829).png': 'Normal',
#  'Normal (1513).png': 'Normal',
#  'Normal (2906).png': 'Normal',
#  'Normal (10875).png': 'Normal',
#  'Normal (6608).png': 'Normal',
#  'Normal (1450).png': 'Normal',
#  'Normal (3147).png': 'Normal',
#  'Normal (1833).png': 'Normal',
#  'Normal (2056).png': 'Normal',
#  'Normal (4846).png': 'Normal',
#  'Normal (10443).png': 'Normal',
#  'Normal (10737).png': 'Normal',
#  'Normal (3601).png': 'Normal',
#  'Normal (3441).png': 'Normal',
#  'Normal (2562).png': 'Normal',
#  'Normal (2268).png': 'Normal',
#  'Normal (1496).png': 'Normal',
#  'Normal (2243).png': 'Normal',
#  'Normal (11055).png': 'Normal',
#  'Normal (2058).png': 'Normal',
#  'Normal (2404).png': 'Normal',
#  'Normal (2066).png': 'Normal',
#  'Normal (4457).png': 'Normal',
#  'Normal (1547).png': 'Normal',
#  'Normal (6558).png': 'Normal',
#  'Normal (2545).png': 'Normal',
#  'Normal (5098).png': 'Normal',
#  'Normal (11995).png': 'Normal',
#  'Normal (5520).png': 'Normal',
#  'Normal (2715).png': 'Normal',
#  'Normal (6208).png': 'Normal',
#  'Normal (3765).png': 'Normal',
#  'Normal (3919).png': 'Normal',
#  'Normal (4449).png': 'Normal',
#  'Normal (11478).png': 'Normal',
#  'Normal (4320).png': 'Normal',
#  'Normal (10973).png': 'Normal',
#  'Normal (5658).png': 'Normal',
#  'Normal (5833).png': 'Normal',
#  'Normal (11863).png': 'Normal',
#  'Normal (10670).png': 'Normal',
#  'Normal (1972).png': 'Normal',
#  'Normal (4065).png': 'Normal',
#  'Normal (2750).png': 'Normal',
#  'Normal (6601).png': 'Normal',
#  'Normal (1656).png': 'Normal',
#  'Normal (2763).png': 'Normal',
#  'Normal (6323).png': 'Normal',
#  'Normal (1904).png': 'Normal',
#  'Normal (3902).png': 'Normal',
#  'Normal (3296).png': 'Normal',
#  'Normal (11190).png': 'Normal',
#  'Normal (4612).png': 'Normal',
#  'Normal (4978).png': 'Normal',
#  'Normal (4600).png': 'Normal',
#  'Normal (4759).png': 'Normal',
#  'Normal (11256).png': 'Normal',
#  'Normal (2638).png': 'Normal',
#  'Normal (4340).png': 'Normal',
#  'Normal (4391).png': 'Normal',
#  'Normal (10450).png': 'Normal',
#  'Normal (3505).png': 'Normal',
#  'Normal (1991).png': 'Normal',
#  'Normal (3014).png': 'Normal',
#  'Normal (1689).png': 'Normal',
#  'Normal (2012).png': 'Normal',
#  'Normal (2267).png': 'Normal',
#  'Normal (4551).png': 'Normal',
#  'Normal (2488).png': 'Normal',
#  'Normal (2871).png': 'Normal',
#  'Normal (5986).png': 'Normal',
#  'Normal (10963).png': 'Normal',
#  'Normal (5538).png': 'Normal',
#  'Normal (6462).png': 'Normal',
#  'Normal (1713).png': 'Normal',
#  'Normal (4125).png': 'Normal',
#  'Normal (6560).png': 'Normal',
#  'Normal (10401).png': 'Normal',
#  'Normal (3816).png': 'Normal',
#  'Normal (10728).png': 'Normal',
#  'Normal (2226).png': 'Normal',
#  'Normal (5794).png': 'Normal',
#  'Normal (11537).png': 'Normal',
#  'Normal (4140).png': 'Normal',
#  'Normal (2835).png': 'Normal',
#  'Normal (10349).png': 'Normal',
#  'Normal (11187).png': 'Normal',
#  'Normal (6170).png': 'Normal',
#  'Normal (4176).png': 'Normal',
#  'Normal (5674).png': 'Normal',
#  'Normal (11267).png': 'Normal',
#  'Normal (6600).png': 'Normal',
#  'Normal (1553).png': 'Normal',
#  'Normal (3371).png': 'Normal',
#  'Normal (11298).png': 'Normal',
#  'Normal (4512).png': 'Normal',
#  'Normal (11590).png': 'Normal',
#  'Normal (3413).png': 'Normal',
#  'Normal (5442).png': 'Normal',
#  'Normal (4944).png': 'Normal',
#  'Normal (5138).png': 'Normal',
#  'Normal (5413).png': 'Normal',
#  'Normal (10705).png': 'Normal',
#  'Normal (5750).png': 'Normal',
#  'Normal (4450).png': 'Normal',
#  'Normal (1486).png': 'Normal',
#  'Normal (4918).png': 'Normal',
#  'Normal (6553).png': 'Normal',
#  'Normal (4643).png': 'Normal',
#  'Normal (11086).png': 'Normal',
#  'Normal (11936).png': 'Normal',
#  'Normal (2679).png': 'Normal',
#  'Normal (2735).png': 'Normal',
#  'Normal (10938).png': 'Normal',
#  'Normal (2778).png': 'Normal',
#  'Normal (1478).png': 'Normal',
#  'Normal (4286).png': 'Normal',
#  'Normal (11838).png': 'Normal',
#  'Normal (6416).png': 'Normal',
#  'Normal (4437).png': 'Normal',
#  'Normal (3938).png': 'Normal',
#  'Normal (11726).png': 'Normal',
#  'Normal (3421).png': 'Normal',
#  'Normal (2990).png': 'Normal',
#  'Normal (4911).png': 'Normal',
#  'Normal (1760).png': 'Normal',
#  'Normal (5960).png': 'Normal',
#  'Normal (2600).png': 'Normal',
#  'Normal (1684).png': 'Normal',
#  'Normal (4916).png': 'Normal',
#  'Normal (4830).png': 'Normal',
#  'Normal (1634).png': 'Normal',
#  'Normal (6333).png': 'Normal',
#  'Normal (6224).png': 'Normal',
#  'Normal (2699).png': 'Normal',
#  'Normal (2932).png': 'Normal',
#  'Normal (5410).png': 'Normal',
#  'Normal (1419).png': 'Normal',
#  'Normal (6490).png': 'Normal',
#  'Normal (10642).png': 'Normal',
#  'Normal (10921).png': 'Normal',
#  'Normal (5530).png': 'Normal',
#  'Normal (3030).png': 'Normal',
#  'Normal (5334).png': 'Normal',
#  'Normal (5601).png': 'Normal',
#  'Normal (6521).png': 'Normal',
#  'Normal (5594).png': 'Normal',
#  'Normal (11322).png': 'Normal',
#  'Normal (1779).png': 'Normal',
#  'Normal (3276).png': 'Normal',
#  'Normal (11206).png': 'Normal',
#  'Normal (1693).png': 'Normal',
#  'Normal (3575).png': 'Normal',
#  'Normal (6116).png': 'Normal',
#  'Normal (5993).png': 'Normal',
#  'Normal (10293).png': 'Normal',
#  'Normal (6385).png': 'Normal',
#  'Normal (6280).png': 'Normal',
#  'Normal (6329).png': 'Normal',
#  'Normal (3767).png': 'Normal',
#  'Normal (10421).png': 'Normal',
#  'Normal (11597).png': 'Normal',
#  'Normal (4461).png': 'Normal',
#  'Normal (4458).png': 'Normal',
#  'Normal (10777).png': 'Normal',
#  'Normal (10438).png': 'Normal',
#  'Normal (2793).png': 'Normal',
#  'Normal (5610).png': 'Normal',
#  'Normal (11672).png': 'Normal',
#  'Normal (1997).png': 'Normal',
#  'Normal (4182).png': 'Normal',
#  'Normal (5847).png': 'Normal',
#  'Normal (2566).png': 'Normal',
#  'Normal (10391).png': 'Normal',
#  'Normal (6417).png': 'Normal',
#  'Normal (11300).png': 'Normal',
#  'Normal (11162).png': 'Normal',
#  'Normal (4948).png': 'Normal',
#  'Normal (2659).png': 'Normal',
#  'Normal (3055).png': 'Normal',
#  'Normal (10717).png': 'Normal',
#  'Normal (1946).png': 'Normal',
#  'Normal (1898).png': 'Normal',
#  'Normal (2533).png': 'Normal',
#  'Normal (6469).png': 'Normal',
#  'Normal (5193).png': 'Normal',
#  'Normal (2846).png': 'Normal',
#  'Normal (2776).png': 'Normal',
#  'Normal (2893).png': 'Normal',
#  'Normal (2645).png': 'Normal',
#  'Normal (5721).png': 'Normal',
#  'Normal (1435).png': 'Normal',
#  'Normal (3635).png': 'Normal',
#  'Normal (5677).png': 'Normal',
#  'Normal (1990).png': 'Normal',
#  'Normal (2060).png': 'Normal',
#  'Normal (2895).png': 'Normal',
#  'Normal (10533).png': 'Normal',
#  'Normal (2361).png': 'Normal',
#  'Normal (11506).png': 'Normal',
#  'Normal (4511).png': 'Normal',
#  'Normal (5332).png': 'Normal',
#  'Normal (1882).png': 'Normal',
#  'Normal (3860).png': 'Normal',
#  'Normal (1958).png': 'Normal',
#  'Normal (5292).png': 'Normal',
#  'Normal (5560).png': 'Normal',
#  'Normal (5264).png': 'Normal',
#  'Normal (5583).png': 'Normal',
#  'Normal (4808).png': 'Normal',
#  'Normal (3264).png': 'Normal',
#  'Normal (3177).png': 'Normal',
#  'Normal (2193).png': 'Normal',
#  'Normal (5416).png': 'Normal',
#  'Normal (11099).png': 'Normal',
#  'Normal (4221).png': 'Normal',
#  'Normal (2941).png': 'Normal',
#  'Normal (6538).png': 'Normal',
#  'Normal (4704).png': 'Normal',
#  'Normal (1846).png': 'Normal',
#  'Normal (1967).png': 'Normal',
#  'Normal (4966).png': 'Normal',
#  'Normal (6087).png': 'Normal',
#  'Normal (10491).png': 'Normal',
#  ...}

# %%
train_df1 = pd.DataFrame(dict_img.items(), columns=['file_names', 'lables'])

train_df1
# Out:
#                  file_names     lables
# 0         Normal (6599).png     Normal
# 1         Normal (2553).png     Normal
# 2         Normal (5219).png     Normal
# 3         Normal (1914).png     Normal
# 4         Normal (3940).png     Normal
# ...                     ...        ...
# 21710  non_COVID (1093).png  Non-COVID
# 21711  non_COVID (7242).png  Non-COVID
# 21712  non_COVID (6862).png  Non-COVID
# 21713  non_COVID (7627).png  Non-COVID
# 21714  non_COVID (9386).png  Non-COVID
#
# [21715 rows x 2 columns]

# %%
# tao danh sach chua file_name image va label
def create_list(path_folder):
    label = os.listdir(path_folder)
    img_label_list =[]
    for lbl in label:
        list_file_name = os.listdir(path_folder +lbl +'/images')
        img_label_list+=[(file_name, lbl) for file_name in list_file_name] # https://www.stackvidhya.com/concatenate-lists-in-python/#:~:text=You%20can%20concatenate%20multiple%20lists,single%20list%20in%20one%20shot
    return img_label_list

# %%
train_list = create_list(lung_data+'Train/')
val_list = create_list(lung_data+'Val/')
test_list = create_list(lung_data+'Test/')

# %%
#tao table (dataframe) để lưu img_label_list
train_df = pd.DataFrame(train_list, columns = ['file_name', 'label'])
val_df = pd.DataFrame(val_list, columns = ['file_name', 'label'])
test_df = pd.DataFrame(test_list, columns = ['file_name', 'label'])

# %%
# ghi file csv 
train_df.to_csv(lung_data+'train.csv',header=True, index = False) #ghi file csv, header = column name, if index = True then add 1 columns
val_df.to_csv(lung_data+'val.csv',header=True, index = False)
test_df.to_csv(lung_data+'test.csv',header=True, index = False)

# %%
# doc file csv
train_csv = pd.read_csv(lung_data+'train.csv') # doc file csv
val_csv = pd.read_csv(lung_data+'val.csv') # doc file csv
test_csv = pd.read_csv(lung_data+'test.csv') # doc file csv

# %%
# ve phan bo data tren train, val, test
# https://stackabuse.com/matplotlib-bar-plot-tutorial-and-examples/
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm

len_train , len_val, len_test = len(train_csv), len(val_csv), len(test_csv)

# print(len_train , len_val, len_test)
x = ['Train', 'Val', 'Test']
y = [len_train, len_val, len_test]
plt.bar(x, y, color = ['b', 'g', 'r'], width=0.5)
plt.show()

# %%
# dem so luong cac class trong train_csv
# https://re-thought.com/pandas-value_counts/#:~:text=The%20value_counts%20%28%29%20function%20is%20used%20to%20get,the%20first%20element%20is%20the%20most%20frequently-occurring%20element.

lst_train = list(train_csv['label'].value_counts())
lst_val = list(val_csv['label'].value_counts())
lst_test = list(test_csv['label'].value_counts())

# %%
test_csv['label'].value_counts()
# Out:
# COVID-19     2395
# Non-COVID    2253
# Normal       2140
# Name: label, dtype: int64

# %%
visualize_distribute_dataset(lst_train, lst_val, lst_test)

# %%
train_dataset = ImageDataset(train_csv, lung_data + 'Train', augs)
train_dataloader = DataLoader(train_dataset, batch_size = 8, shuffle=True)
img, mask, label, file_name = next(iter(train_dataloader))
img, mask = img_de_normalize(img, mask)
imshow_img_mask(img,mask,label)

# %%
transfms_M_STD = A.Compose([
    A.Resize(256,256),
    A.Normalize(mean = [0.], std =[1.]), # scale pixel values from [0,255] to [0,1]
    ToTensorV2() 
])

train_dt = ImageDataset(train_csv, lung_data+ 'Train', transfms_M_STD)
train_loader = DataLoader(train_dt, batch_size=32, shuffle = False)
img, _, _, _  = next(iter(train_loader))
print(img.size())
# Out:
# torch.Size([32, 1, 256, 256])

# %%
def compute_mean_std(dataloader):
    mean1 = 0.
    std1 = 0.
    nb_samples = 0.
    for data, _, _, _ in tqdm(dataloader):
        batch_samples = data.size(0)

        # Rearrange data to be the shape of [B, C, W * H]
        data = data.view(batch_samples, data.size(1), -1) # torch.Size([32, 1, 65536])
        
        # Compute mean and std here
        mean1 += data.mean(2).sum(0) #tinh mean theo width*height va lay tong theo batch_size
        # print(data.mean(2).size())
        std1 += data.std(2).sum(0)

        # Update total number of images
        nb_samples += batch_samples
    mean1 /= nb_samples
    std1 /= nb_samples

    return mean1, std1

mean, std = compute_mean_std(train_loader)
print(mean, std)
# Out:
# 100%|██████████| 679/679 [00:33<00:00, 20.37it/s]
# tensor([0.5128]) tensor([0.2220])

# %%
# import os
# import torch

# from tqdm.notebook import tqdm
# from time import time
 
# N_CHANNELS = 1
 
# train_dataset = ImageDataset(train_csv, lung_data + 'Train', augs)
# train_dataloader = DataLoader(train_dataset, batch_size = 8, shuffle=True)
 
# before = time()
# mean = torch.zeros(1)
# std = torch.zeros(1)
# print('==> Computing mean and std..')
# for inputs, _labels, _, _ in tqdm(train_dataloader):
#     for i in range(N_CHANNELS):
#         mean[i] += inputs[:,i,:,:].mean()
#         std[i] += inputs[:,i,:,:].std()
# mean.div_(len(train_dataset))
# std.div_(len(train_dataset))
# print(mean, std)
 
# print("time elapsed: ", time()-before)
